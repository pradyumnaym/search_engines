# %%
import os
import json
import requests
import random
import validators

from dotenv import load_dotenv
from tqdm import tqdm

# %%
# !pip install accelerate --upgrade
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.30.1)
# Collecting accelerate
#   Downloading accelerate-0.31.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.23.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.30.1
#     Uninstalling accelerate-0.30.1:
#       Successfully uninstalled accelerate-0.30.1
# Successfully installed accelerate-0.31.0
# Looking in indexes: https://pypi.org/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (2.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 13.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.43.1

# %% [markdown]
# #### Data crawling frontier
#
# To create a high-recall search engine related to Tübingen, we need a targeted approach to crawling information from the web. If we were to randomly pick a document from the web, the probability of it being related to Tübingen is practically 0. Starting with a few well-known websites (e.g: facebook, etc) will not be effective, since these websites host information about the entire world. We will not 'come across' Tübingen-related information easily.
#
# So, our goal is to first ensure we collect only information about Tübingen, with as little effort (in terms of number of pages visited) as possible. As we saw in `retrieve_map_data.py`, the Google Maps API is restricted to only 20 results per API call, rendering it hard to use to create a frontier of all Tübingen related items. Hence, we now try to gather information about Tübingen from OpenStreetMaps. OpenStreetMaps has an API that accepts a bounding box and returns all [nodes](https://wiki.openstreetmap.org/wiki/Elements#Node) within that bounding box.
#
# Below, we filter out important nodes that people might want to search about.

# %%
# A list of node "types" we want to retrieve from open street maps.
# Reference: https://wiki.openstreetmap.org/wiki/Map_features
place_types = [
    'amenity',
    'building',
    'craft',
    'emergency',
    'healthcare',
    'historic',
    'leisure',
    #'natural',
    'office',
    'public_transport',
    'shop',
    'sport',
    'tourism'
]

# The coordinates for a bounding box around Tübingen and surrounding areas.
min_lat, min_lon, max_lat, max_lon = 48.4524, 8.921, 48.5659, 9.1394

total_nodes = 0
node_data = {}

for place_type in place_types:

#  Construct the Overpass QL query for nodes of a particular type
    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f"""
[out:json];
node[{place_type}]({min_lat},{min_lon},{max_lat},{max_lon});
out body;
"""

    # Execute the query
    response = requests.post(overpass_url, data=overpass_query).json()

    node_data[place_type] = response['elements']
    total_nodes += len(response['elements'])

# Dump the node data to a JSON file.
with open('../data/places_OSM.json', 'w') as fp:
    json.dump(node_data, fp, indent=4)

print(f"Gathered {total_nodes} nodes in and around Tübingen!")
print("%20s %10s"%('Category', '# Nodes'))
for place_type in place_types:
    print("%20s %10s"%(place_type, len(node_data[place_type])))
# Out:
# Gathered 11902 nodes in and around Tübingen!
#
#             Category    # Nodes
#
#              amenity       5726
#
#             building         52
#
#                craft        159
#
#            emergency       1428
#
#           healthcare        292
#
#             historic        375
#
#              leisure        257
#
#               office        363
#
#     public_transport       1261
#
#                 shop        828
#
#                sport         80
#
#              tourism       1081

# %% [markdown]
# #### Node metadata
#
# We see that some nodes already have useful metadata that can be crawled or looked up. We segregate such nodes from nodes that require further processing.

# %%
# Load the node data from the JSON file.
with open('../data/places_OSM.json', 'r') as fp:
    node_data = json.load(fp)

all_nodes = sum(node_data.values(), [])   # Put all types of nodes into one list

useful_tags = [
    'name',
    'url',
    'contact:website',
    'website',
    'operator',
]

nodes_with_info = [x for x in all_nodes if len( set(useful_tags) & set(x['tags']) ) != 0]
nodes_without_info = [x for x in all_nodes if len( set(useful_tags) & set(x['tags']) ) == 0]

print(len(nodes_with_info))
# Out:
# 5254

# %% [markdown]
# #### Difficult nodes
#
# We see that some nodes do not have any useful information, but might be searched by a user. Let us use an LLM to generate keywords for such nodes.

# %%
random.choice(nodes_without_info)
# Out:
# {'type': 'node',
#  'id': 9492154953,
#  'lat': 48.5173896,
#  'lon': 9.0616433,
#  'tags': {'bicycle': 'yes',
#   'colour:back': 'white',
#   'colour:text': 'green',
#   'direction': '65',
#   'direction_northwest': 'Tü-Altstadt 0.8km;Tübingen Hbf 0.4km',
#   'direction_southeast': 'Reutlingen 15km;Tü-Südstadt 1.1km',
#   'guidepost:type': 'table',
#   'information': 'guidepost',
#   'network': 'lcn',
#   'tourism': 'information'}}

# %% [markdown]
# We write a prompt providing an LLM with the node details, and asking it to generate some keywords if possible.

# %%
def generate_prompt_from_node(node):
    """
    Create a prompt that can be used to extract information about an OpenStreetMap Node. 
    
    Argument
    --------
    node: dict, a Node structure obtained from OSM.
    
    Returns
    -------
    str, the prompt asking an LLM for information about the node.
    """
    
    return f"""
I am trying to search for any searchable points in a city, Tübingen. I have retrieved the following information about a point: 

{node}


Please decide if the node is important, if yes, please give me one or two keywords I can use to Google search for this point. If not, simply return "Not Applicable". Please do not print anything else (not even explanations)! Only the keyword, or "Not Applicable". Do not create new lines. Simply output the keywords.
Response:"""

prompts = list(map(generate_prompt_from_node, nodes_without_info))

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "mistralai/Mistral-7B-Instruct-v0.3", device_map="cuda", load_in_4bit=True
)
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3", padding_side="left")

tokenizer.pad_token = tokenizer.eos_token  # Most LLMs don't have a pad token by default

model_inputs = tokenizer(
    prompts[:2], return_tensors="pt", padding=True
).to("cuda")
            
generated_ids = model.generate(max_new_tokens = 20, **model_inputs)
outputs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
# Out:
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/137k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:426: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# 2024-06-20 21:03:31.397363: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-20 21:03:31.397490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-20 21:03:31.515815: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
outputs[1]
# Out:
# '\nI am trying to search for any searchable points in a city, Tübingen. I have retrieved the following information about a point: \n\n{\'type\': \'node\', \'id\': 30933690, \'lat\': 48.5319164, \'lon\': 9.0822537, \'tags\': {\'amenity\': \'recycling\', \'check_date:recycling\': \'2023-09-07\', \'opening_hours\': \'Mo-Fr 09:00-17:00\', \'recycling:glass_bottles\': \'yes\', \'recycling_type\': \'container\'}}\n\n\nPlease decide if the node is important, if yes, please give me one or two keywords I can use to Google search for this point. If not, simply return "Not Applicable". Please do not print anything else (not even explanations)! Only the keyword, or "Not Applicable". Do not create new lines. Simply output the keywords.\nResponse:\nRecycling Center, Container Depot'

# %% [markdown]
# #### Keyword Generation
#
# We now try to extract all possible keywords. Note that, we do not have any other information about these nodes, so we can simply maintain a set of all possible search keywords extracted from these nodes.

# %%
batch_size = 64
keywords = set()
all_outputs = []

def parse_response(response):
    """
    Parse the response of an LLM, and obtain the search keywords.
    
    Arguments
    ---------
    response: str, the LLM response
    
    Returns
    -------
    str, the search keyword (return "" in case of parse error or "Not Applicable" response)
    """
    
    response = response.split('Response:')[1]
    
    if 'Not Applicable' in response:
        return ""
    
    if 'Explanation:' in response:
        response = response.split('Explanation:')[0]
    return response

for i in tqdm(range(101, 103)):  #len(nodes_without_info)//batch_size
    # process this batch of nodes - obtain keywords, update our keyword set.
    batch_prompts = prompts[batch_size * i: batch_size * (i + 1)]
    
    model_inputs = tokenizer(
        batch_prompts, return_tensors="pt", padding=True
    ).to("cuda")
    
    generated_ids = model.generate(max_new_tokens = 20, **model_inputs)
    outputs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    all_outputs.extend(outputs)
    keywords.update(map(parse_response, outputs))

print(keywords)

# %%
keywords
# Out:
# {'',
#  '\n\n"Bench, Inscription"',
#  '\n\n"Bench, Tübingen"',
#  '\n\n"Bench, Wooden"',
#  '\n\n"Concrete bench, Tübingen"',
#  '\n\n"Defibrillator location Tübingen"\n"Emergency defibr',
#  '\n\n"Defibrillator location, Volksbank Tübingen"',
#  '\n\n"Fountain, Tübingen"',
#  '\n\n"Medieval archaeological site, Tübingen"',
#  '\n\n"Metal bench, Tübingen"',
#  '\n\n"Outdoor furniture, Park bench"',
#  '\n\n"Outdoor seating, Wooden bench"',
#  '\n\n"Park bench, Tübingen"',
#  '\n\n"Park bench, Wooden bench"',
#  '\n\n"Public Fountain (No Drinking Water)"',
#  '\n\n"Public seating, Tübingen"',
#  '\n\n"Sculpture, Vogel"',
#  '\n\n"Sitzbank, Tübingen"',
#  '\n\n"Statue of Nymph, Tübingen art"',
#  '\n\n"Tübingen, Germany, Accessible, Emergency"',
#  '\n\n"Waldtoilette Tübingen"\n"Ökologisches',
#  '\n\nArtwork, Historic',
#  '\n\nBicycle parking, Lockers (with fee)',
#  '\n\nBicycle parking, Safe loops parking Tübingen',
#  '\n\nCigarette vending machine, Tübingen',
#  '\n\nCoffee Shop, Snack Bar',
#  '\n\nDecorative Fountain\n\n',
#  '\n\nEmergency bollard, Removable bollard',
#  '\n\nEmergency, Defibrillator',
#  '\n\nFountain, Eberhardskirche Tübingen',
#  '\n\nFountain, Erbsenbrunnen',
#  '\n\nFountain, Tübingen (City Name)',
#  '\n\nFountain, Tübingen (City)',
#  '\n\nGhost bike, Memorial\n\n',
#  '\n\nGuidepost, Information',
#  '\n\nGuidepost;Information',
#  '\n\nHistoric Boundary Stone, Tübingen City',
#  '\n\nHistoric Boundary Stone, Tübingen City Hall',
#  '\n\nHistoric Fountain, Tübingen Marktplatz Entringen\n\n',
#  '\n\nHistoric boundary stone, Tübingen inscription',
#  '\n\nHistoric ruins, Tübingen military site',
#  '\n\nHunting stand, Tübingen\n\n',
#  '\n\nKaiser Augustus Statue Memorial Tübingen',
#  '\n\nMemorial Stele, Tübingen 2008',
#  '\n\nMemorial, Cemetery',
#  '\n\nMemorial, Seifert Brunnen',
#  '\n\nMemorial, Stele',
#  '\n\nMilestone, Kilometerstein',
#  '\n\nMonument, Boundary_stone',
#  '\n\nMonument, Inscription',
#  '\n\nMonument, Memorial Plaque',
#  '\n\nMulti-storey Car Park, Parking Entrance',
#  '\n\nMulti-storey Car Park, Tübingen',
#  '\n\nOutdoor Seating, Stone Bench',
#  '\n\nOutdoor furniture, Wooden bench',
#  '\n\nOutdoor furniture, Wooden bench (Not backrest)',
#  '\n\nOutdoor seating, Stone bench',
#  '\n\nOutdoor shelter, Waldkindergarten Veranda',
#  '\n\nPark, Dog Waste Bin',
#  '\n\nParking Bollard',
#  '\n\nParking Entrance, Private Parking',
#  '\n\nParking Entrance, Private Parking\n\n',
#  '\n\nParking Garage, Underground Parking',
#  '\n\nParking, Accessible\n\n',
#  '\n\nParking, Private\n\n',
#  '\n\nParking, Private Parking',
#  '\n\nParking, Public Space',
#  '\n\nParking, Rathaus Mitarbeiter (Tübingen)',
#  '\n\nParking, Street-side Parking',
#  '\n\nPublic Shower\nPublic Shower Facility',
#  '\n\nPublic Transport Tickets Vending Machine, Tübingen',
#  '\n\nPublic Transport Tickets, Vending Machine',
#  '\n\nRegina Burckhardt-Bardili; Memorial Plaque',
#  '\n\nRottenburg am Neckar, Vacant Shop',
#  '\n\nShelter, Bühlerwald-Hütte',
#  '\n\nTicket Validator Kiosk, Public Transport\n\n',
#  '\n\nTourism, Guidepost',
#  '\n\nTourist Information, Guidepost',
#  '\n\nTourist Information, Schönbuch Hiking Trails',
#  '\n\nToy Vending Machine (Indoor)\n\n',
#  '\n\nTübingen History Board, Tübingen Information Board',
#  '\n\nTübingen History Board, Tübingen Tourist Information',
#  '\n\nTübingen deer feeding area, Deer feeding point Tübingen',
#  '\n\nTübingen viewpoint, Accessible viewpoint',
#  '\n\nTübingen viewpoint, Limited accessibility viewpoint',
#  '\n\nTübingen viewpoint, Tübingen direction SE-NW',
#  '\n\nTübingen, Ehinger Platz',
#  '\n\nTübingen, Guidepost',
#  '\n\nTübingen, Marktstraße 11, 82606',
#  '\n\nUnderground Concrete Parking\n\n',
#  '\n\nUnderground Parking Entrance, Tübingen',
#  '\n\nUnderground Parking, Tübingen',
#  '\n\nUnderground parking Tübingen',
#  '\n\nUnderground parking, Tübingen',
#  '\n\nVending Machine, Drinks 24/7 Tübingen',
#  '\n\nVending machine, Cigarettes',
#  '\n\nVending machine, Drinks (Tübingen)',
#  '\n\nViewpoint, Panorama Tübingen',
#  '\n\nViewpoint, Tübingen',
#  '\n\nWaldlehrpfad Einsiedel, Tübingen',
#  '\n\nWaldlehrpfad, Tübingen',
#  '\n\naccessible, emergency_services',
#  '\n\nbench, Tübingen',
#  '\n\nbench, seating',
#  '\n\nbicycle parking Tübingen',
#  '\n\nbicycle parking, Tübingen',
#  '\n\nbicycle parking, emergency parking',
#  '\n\nbicycle parking, lockers',
#  '\n\nbollard, parking\n\n',
#  '\n\nbus_stop, public_transportation',
#  '\n\nchurch, Tübingen Catholic Church',
#  '\n\ndefibrillator location, Gymnastikraum Tübingen',
#  '\n\ndefibrillator location, Halle 3 Sanitätsraum',
#  '\n\ndefibrillator location, Sanitätsraum',
#  '\n\ndefibrillator location, Service-Center Bauen',
#  '\n\ndefibrillator location, Tübingen',
#  '\n\ndefibrillator location, Tübingen 58 Aixer Straße',
#  '\n\ndefibrillator location, Volksbank Tübingen',
#  '\n\ndefibrillator location, emergency services',
#  '\n\ndefibrillator location, indoor emergency\n\n',
#  '\n\ndefibrillator, Information beim Leergutautomat',
#  '\n\ndefibrillator, Tübingen University Hospital (implied by indoor and location',
#  '\n\ndefibrillator, Tübingen city hall\n\n',
#  '\n\ndefibrillator, indoor_facility',
#  '\n\ndefibrillator, indoor_location',
#  '\n\ndoctors, Tübingen',
#  '\n\nemergency_ward, hospital',
#  '\n\nguidepost, Tübingen',
#  '\n\nguidepost, Tübingen city center',
#  '\n\nguidepost, information',
#  '\n\nhiking, Ammertal',
#  '\n\nhistoric shrine, Christian shrine',
#  '\n\nhistoric,boundary_stone',
#  '\n\nhistoric_boundary_stone',
#  '\n\nletter_box, Tübingen',
#  '\n\nloading_dock, Tübingen',
#  '\n\nlounge, Cafe',
#  '\n\nlounger, Tübingen',
#  '\n\nmemorial cross Tübingen',
#  '\n\nmemorial plaque Tübingen',
#  '\n\nmemorial stone Tübingen',
#  '\n\nmemorial, Entringens',
#  '\n\nmemorial, Karl Stanik',
#  '\n\nmemorial, Tübingen',
#  '\n\nplace_of_worship, Catholic church',
#  '\n\nprivate toilets Tübingen',
#  '\n\nsculpture, Gôgen-Denkmal',
#  '\n\nsculpture, Tübingen art',
#  '\n\nshrine, Tübingen memorial',
#  '\n\ntax_advisor Tübingen',
#  '\n\ntaxi stand, Tübingen\n\n',
#  '\n\ntelephone booth\npublic call box',
#  '\n\ntelephone_booth\npublic_call_box',
#  '\n\ntourist information, guidepost',
#  '\n\nvacant cafe Tübingen',
#  '\n\nvacant shop\n\n',
#  '\n\nvacuum_cleaner_rental_Tübingen\nvacuum',
#  '\n\nvending machine drinks Tübingen\n\n',
#  '\n\nvending machine, Tübingen',
#  '\n\nvending machine, chewing gums',
#  '\n\nvending machine, cigarettes',
#  '\n\nvending machine, cigarettes and telephone vouchers',
#  '\n\nvending machine, drinks\n\n',
#  '\n\nvending machine, excrement bags',
#  '\n\nvending machine, sweets',
#  '\n\nvending machine, sweets shop',
#  '\n\nviewpoint Tübingen',
#  '\n\nviewpoint, Tübingen',
#  '\n\nwaste_basket, trash_can',
#  '\n\nwaste_bin, dog_waste_bin',
#  '\n\nwayside shrine, Christian shrine',
#  '\n"Outdoor seating, Concrete bench"',
#  '\n"Park bench, Seating area"',
#  '\n24/7 Farm Store, Tübingen',
#  '\n24/7 defibrillator, Indoor defibrillator',
#  '\nAccessible Public Toilets, Tübingen',
#  '\nArtist, Martin',
#  '\nArtwork, Relief',
#  '\nArtwork, Tübingen',
#  '\nBarbecue Grill, Tübingen',
#  '\nBarbecue area, Fire pit location',
#  '\nBarbecue area, Tübingen',
#  '\nBarbecue, Tübingen',
#  '\nBasketball court, Outdoor basketball court',
#  '\nBasketball court, Tübingen',
#  '\nBicycle parking Tübingen',
#  '\nBicycle parking stands, Covered bicycle parking',
#  '\nBicycle parking stands, Covered bicycle parking Tübingen',
#  '\nBicycle parking stands, Tübingen',
#  '\nBicycle parking, Covered bicycle parking',
#  '\nBicycle parking, Indoor bicycle parking',
#  '\nBicycle parking, Stand\n\n',
#  '\nBicycle parking, Tübingen',
#  '\nBicycle parking, Wall loops',
#  '\nBicycle parking, Wall loops parking',
#  '\nBicycle parking, Wall loops parking Tübingen',
#  '\nBiergarten Tübingen, Limited Accessibility Biergarten Tübing',
#  '\nCafe, Tübingen',
#  '\nCafé, Lounger',
#  '\nCafé, Outdoor seating',
#  '\nCar wash, Tübingen',
#  '\nChess Ground, Tübingen\n\n',
#  '\nChess Table, Outdoor Recreation',
#  '\nClock tower, City center',
#  '\nClock tower, Tübingen city center',
#  '\nClock, Street\n\n',
#  '\nClock, Street Facing\n\n',
#  '\nClock, Sundial',
#  '\nClock, Sundial (Indoor)',
#  '\nCompressed Air Station Fee\nCompressed Air Station Paid Access',
#  '\nCompressed Air Station, Tübingen',
#  '\nDefibrillator Location, Sporthalle Tübingen',
#  '\nDelivery point, Access point',
#  '\nDentist, Tübingen Dental Clinic',
#  '\nDog waste bin, Tübingen',
#  '\nDrinking water fountain, Accessible drinking water fountain',
#  '\nDrinking water fountain, Public tap',
#  '\nDrinking water fountain, Public water fountain',
#  '\nElevator, Building Entrance',
#  '\nEmergency Access, Lift-Gated Destination',
#  '\nEmergency Barrier',
#  '\nEmergency Barrier, Lift Gate Tübingen',
#  '\nEmergency Ward Entrance, Rescue Service',
#  '\nEmergency, Bollard (Rising)',
#  '\nEmergency, Defibrillator',
#  '\nEquestrian field, Tübingen',
#  '\nExcrement Bags Vending Machine Tübingen',
#  '\nFire hydrant location, Emergency services Tübingen',
#  '\nFire_hydrant\nEmergency_services_facility',
#  '\nFirepit Tübingen\n\n',
#  '\nFirepit location, Tübingen',
#  '\nFirepit, Barbecue',
#  '\nFitness Station, Elliptical Trainer',
#  '\nFountain Tübingen\n\n',
#  '\nFountain, Nervenklinik Tübingen',
#  '\nFountain, Tübingen',
#  '\nFree parking, Accessible parking',
#  '\nFree parking, Wheelchair accessible parking',
#  '\nGarbage bin, Recycling point',
#  '\nGomaringen, Bahnhofstraße',
#  '\nGrill, Barbecue',
#  '\nGuidepost, Information',
#  '\nHistoric Catholic Cross, Tübingen',
#  '\nHistoric Cross, Conciliation Cross',
#  '\nHistoric Cross, Wayside Cross',
#  '\nHistoric boundary stone, Tübingen city symbol',
#  '\nHistoric cross, Tübingen (Germany)',
#  '\nHistoric cross, Vandalized cross',
#  '\nHistoric water well, Tübingen',
#  '\nHistoric water well, out of order',
#  '\nHistorical Column for Horse Tethering, Accessible',
#  '\nHistorical Column, Pferdeanbinden (Historical Horse Tethering',
#  '\nHistorical Linden Allee, Memorial',
#  '\nHunting stand, Shooting range',
#  '\nHunting stand, Tübingen',
#  '\nHunting stand, Tübingen\n\n',
#  '\nHunting_stand Tübingen',
#  '\nHunting_stand Tübingen\n\n',
#  '\nLitter bin, Steel bin',
#  '\nLitter bin, Steel litter bin',
#  '\nMemorial bench, St. Remigius Chapel',
#  '\nMotorcycle parking Tübingen',
#  '\nMotorcycle parking, Bicycle parking (wall_loops)',
#  '\nMulti-storey Car Park, Parking Entrance',
#  '\nMulti-storey Car Park, Tübingen',
#  '\nNaturschutzgebiet, Viewpoint',
#  '\nOutdoor Furniture, Bench (No Backrest)',
#  '\nOutdoor Furniture, Park Bench',
#  '\nOutdoor Furniture, Public Seating',
#  '\nOutdoor Furniture, Stone Bench',
#  '\nOutdoor Seating Area\nPark Bench',
#  '\nOutdoor Seating Area\nPublic Bench',
#  '\nOutdoor Seating Area, Park Bench',
#  '\nOutdoor Seating Area, Public Bench',
#  '\nOutdoor Seating, Bench',
#  '\nOutdoor Seating, Park Bench',
#  '\nOutdoor Seating, Stone Bench',
#  '\nOutdoor dining, Restaurant',
#  '\nOutdoor furniture, Bench',
#  '\nOutdoor furniture, Bench (No backrest)',
#  '\nOutdoor furniture, Bench (no backrest)',
#  '\nOutdoor furniture, Blue bench',
#  '\nOutdoor furniture, Concrete bench',
#  '\nOutdoor furniture, Park bench',
#  '\nOutdoor furniture, Seating area',
#  '\nOutdoor furniture, Wooden bench',
#  '\nOutdoor seating area, Park bench',
#  '\nOutdoor seating area, Public bench',
#  '\nOutdoor seating area, Tübingen',
#  '\nOutdoor seating, Bench',
#  '\nOutdoor seating, Bench (8 seats)',
#  '\nOutdoor seating, Concrete bench',
#  '\nOutdoor seating, Park bench',
#  '\nOutdoor seating, Public bench',
#  '\nOutdoor seating, Table tennis',
#  '\nOutdoor wooden public bookcase\n\n',
#  '\nPaid parking space, Disabled parking space',
#  '\nPark bench, Accessible',
#  '\nPark bench, Altliege',
#  '\nPark bench, Altliege (Tübingen)',
#  '\nPark bench, Outdoor seating',
#  '\nPark bench, Plastic bench',
#  '\nPark bench, Public shelter',
#  '\nPark bench, Seating area',
#  '\nPark bench, Sitzbank',
#  '\nPark bench, Tübingen',
#  '\nPark bench, Tübingen city',
#  '\nPark bench, Wooden bench',
#  '\nParking Entrance Tübingen',
#  '\nParking Entrance Tübingen\n\n',
#  '\nParking Entrance, Gate',
#  '\nParking Entrance, Private Parking',
#  '\nParking Entrance, Surface Parking',
#  '\nParking Entrance, Tübingen',
#  '\nParking Entrance/Exit, Tübingen',
#  '\nParking Garage, Underground Parking',
#  '\nParking Space, Tübingen',
#  '\nParking Tickets Vending Machine',
#  '\nParking Tickets Vending Machine\n\n',
#  '\nParking Tickets Vending Machine Tübingen',
#  '\nParking Tickets Vending Machine, Accessible',
#  '\nParking Tickets Vending Machine, Tübingen',
#  '\nParking Underground Entrance, Tübingen',
#  '\nParking Underground, Tübingen',
#  '\nParking space, Disabled parking\n\n',
#  '\nParking, Accessible Parking',
#  '\nParking, Asphalt Surface',
#  '\nParking, Destination',
#  '\nParking, Disabled Parking',
#  '\nParking, Free Parking',
#  '\nParking, Gravel Parking',
#  '\nParking, Handicapped Parking',
#  '\nParking, Königstraße 11, Tübingen',
#  '\nParking, Limited Accessibility',
#  '\nParking, Paid Parking',
#  '\nParking, Private Parking',
#  '\nParking, Street Side Parking',
#  '\nParking, Surface Parking',
#  '\nParking, Surface parking',
#  '\nParking, Tübingen',
#  '\nParking, Visitor Parking',
#  '\nPhotovoltaic System, Solar Energy',
#  '\nPicnic Area, Tübingen',
#  '\nPicnic Spot, Private Area',
#  '\nPicnic Table, Tübingen',
#  '\nPicnic area, Tübingen',
#  '\nPicnic shelter, Tübingen',
#  '\nPicnic site, BBQ area',
#  '\nPicnic site, Barbecue area',
#  '\nPicnic site, Firepit',
#  '\nPicnic site, Grillplatz bei Entringen (Google search: "Pic',
#  '\nPicnic site, Tübingen',
#  '\nPicnic spot, Outdoor seating',
#  '\nPicnic spot, Tübingen',
#  '\nPicnic spot, Wooden picnic table',
#  '\nPicnic table, Bench',
#  '\nPicnic table, Holzacker park, Tübingen-Hirschau',
#  '\nPicnic_spot, Tübingen',
#  '\nPost office, Mailbox',
#  '\nPrivate parking, Surface parking',
#  '\nPub, Tübingen',
#  '\nPublic Bookcase 24/7\n\n',
#  '\nPublic Bookcase Shelf\n\n',
#  '\nPublic Bookcase, Outdoor Library',
#  '\nPublic Bookcase, Wooden Cabinet',
#  '\nPublic Library\nBook Exchange\n\n',
#  '\nPublic Table Tennis Court\nTable Tennis Facility',
#  '\nPublic Toilets\nNot Accessible for Wheelchair Users',
#  '\nPublic Toilets (Paid)',
#  '\nPublic Toilets for Wheelchair Users, Accessible Toilets Tübingen',
#  '\nPublic Toilets with Wheelchair Access and Changing Table, Free of Charge (',
#  '\nPublic Toilets with Wheelchair Access, Paid Toilets',
#  '\nPublic Toilets, Accessible Toilets',
#  '\nPublic Toilets, Accessible Toilets, Tübingen, Kreuzg',
#  '\nPublic Toilets, Limited Accessibility Tübingen',
#  '\nPublic Toilets, Mobile Toilet Cabin',
#  '\nPublic Toilets, Tübingen',
#  '\nPublic Toilets, Tübingen\n\n',
#  '\nPublic Toilets, Tübingen (limited wheelchair access)',
#  '\nPublic Toilets, Tübingen (limited wheelchair accessibility)',
#  '\nPublic Transport Tickets Vending Machine (Indoor) Tübingen',
#  '\nPublic Transport Tickets Vending Machine Tübingen',
#  '\nPublic Transport Tickets Vending Machine, Tübingen',
#  '\nRecycling Center, Bischof-Moser-Straße',
#  '\nRecycling Center, Container Depot',
#  '\nRecycling Center, Glass Bottles Recycling',
#  '\nRecycling Center, Metal Scrap Yard',
#  '\nRecycling Center, Paper Recycling',
#  '\nRecycling Center, Plastic Bin',
#  '\nRecycling Center, Plastic Recycling',
#  '\nRecycling Center, Trash Can',
#  '\nRecycling Center, Trash Disposal Facility',
#  '\nRecycling Center, Waste Bin',
#  '\nRecycling Center, Waste Disposal',
#  '\nRecycling Center, Waste Management',
#  '\nRecycling Center, Winter Collection Point',
#  '\nRecycling Center, Wood Collection Point',
#  '\nRecycling Container, 24/7 Glass Bottles Recycling (Whe',
#  '\nRecycling Container, Glass Bottles Recycling',
#  '\nRecycling Container, Paper Recycling',
#  '\nRecycling bin, Green metal bin',
#  '\nRecycling container for glass bottles, Tübingen',
#  '\nRecycling container, Glass bottles',
#  '\nRecycling container, Glass bottles recycling',
#  '\nRecycling container, Glass bottles recycling Tübingen',
#  '\nRecycling, Metal Recycling',
#  '\nRecycling, Waste Bin',
#  '\nRecycling, Waste Management',
#  '\nRelaxbank Bench',
#  '\nRestaurant, Outdoor dining',
#  '\nRottenburg am Neckar, Convenience Store',
#  '\nRottenburg am Neckar, Maieräckerstraße 18',
#  '\nRottenburg am Neckar, Physiotherapist',
#  '\nRottenburg am Neckar, Storage Rental',
#  '\nRuins of Tübingen, Tübingen historic sites',
#  '\nSanitary Dump Station, Tübingen',
#  '\nShelter with fireplace Tübingen',
#  '\nShelter, Emergency shelter',
#  '\nShelter, Tübingen',
#  '\nSoccer field, Grass pitch',
#  '\nStreet parking Tübingen',
#  '\nTable Tennis Court, Tübingen',
#  '\nTelephone booth\nPublic call box',
#  '\nTelephone booth, Accessible telephone booth',
#  '\nTour, Information (or) Vesper-Tour, Information (or) H',
#  '\nTourism, Information',
#  '\nTourist Information, Board',
#  '\nTourist Information, Geology Information',
#  '\nTourist Information, Geology Map',
#  '\nTourist Information, Guidepost',
#  '\nTourist Information, Historical Board',
#  '\nTourist Information, Historical Map',
#  '\nTourist Information, Information Board',
#  '\nTourist Information, Map Information',
#  '\nTourist Information, Nature Board',
#  '\nTourist Information, Notice Board',
#  '\nTourist Information, Wildlife Board',
#  '\nTourist Information, Zick-Zack-Wegle',
#  '\nTrash bin, Waste basket',
#  '\nTrash bin, Waste basket (Tübingen)',
#  '\nTrash bin, Waste basket Tübingen',
#  '\nTrolley Bay, Parking\n\n',
#  '\nTrolley_bay, Parking\n\n',
#  '\nTübingen Hbf, Guidepost',
#  '\nTübingen History, Tübingen Tourism Information',
#  '\nTübingen Information Board, Tübingen Tourist Information',
#  '\nTübingen bench, Christiane Nüsslein-Volhard dedication',
#  '\nTübingen wildlife board, Tübingen information board',
#  '\nTübingen, City Hall',
#  '\nTübingen, Guidepost',
#  '\nTübingen, Massage',
#  '\nTübinger Straße, Tübingen',
#  '\nUnderground Parking Entrance, Tübingen',
#  '\nUnderground Parking Tübingen',
#  '\nUnderground Parking, Tübingen',
#  '\nUnderground parking, Tübingen',
#  '\nViewpoint, Bench',
#  '\nViewpoint, Limited Accessibility',
#  '\nViewpoint, Tübingen',
#  '\nWater tap, Drinking water',
#  '\nWeather shelter, Emergency shelter',
#  '\nacupuncture clinic, healthcare Tübingen',
#  '\narchaeological site, Tumulus',
#  '\nartwork Tübingen',
#  '\nartwork, sculpture',
#  '\nassembly_point Tübingen',
#  '\natm machine bank cashpoint Tübingen',
#  '\nbar, Tübingen',
#  '\nbbq_area, public_bbq_spot',
#  '\nbbq_grill_location, Tübingen_grill_spot',
#  '\nbench, Tübingen',
#  '\nbench, seating',
#  '\nbicycle parking Tübingen',
#  '\nbicycle parking stands Tübingen',
#  '\nbicycle parking, Tübingen',
#  '\nbicycle parking, stands',
#  '\nbicycle parking, stands (5412419730)',
#  '\nbicycle parking, stands (8)',
#  '\nbicycle parking, stands (Tübingen)',
#  '\nbicycle parking, wall loops',
#  '\nbicycle repair station Tübingen',
#  '\nbicycle repair station, Tübingen',
#  '\nbuilding shed Tübingen',
#  '\ncafe Tübingen',
#  '\ncanteen, Tübingen',
#  '\ncar_repair Tübingen',
#  '\ncharging_station Tübingen',
#  '\ncharging_station, Tübingen',
#  '\nclimbing wall\ntübingen climbing wall\n(or)\nclimbing',
#  '\nclock, sundial',
#  '\ndefibrillator Tübingen',
#  '\ndefibrillator location, Hügelstraße 13, 7207',
#  '\ndefibrillator location, Kingersheimer Straße',
#  '\ndefibrillator location, Lehrerumkleide (EG)',
#  '\ndefibrillator location, Nonnengasse 19, 7207',
#  '\ndefibrillator location, Schmiedtorstraße 4, 7207',
#  '\ndefibrillator location, Tübingen 72072 Galgenberg',
#  '\ndefibrillator location, Tübingen Friedrichstraße 21',
#  '\ndefibrillator location, Tübingen Frischlinstraße 4',
#  '\ndefibrillator location, Tübingen address',
#  '\ndefibrillator location, Tübingen city hall',
#  '\ndefibrillator location, Tübingen office building',
#  '\ndefibrillator location, emergency services',
#  '\ndefibrillator location, indoor emergency\n\n',
#  '\ndefibrillator location, office parking\n\n',
#  '\ndefibrillator, emergency_services',
#  '\ndefibrillator, emergency_station',
#  '\ndoctors, Tübingen',
#  '\ndrinking water fountain',
#  '\ndrinking water, fountain',
#  '\ndrinking_water_tap, city_water_source',
#  '\nemergency, defibrillator',
#  '\nemergency_phone, Tübingen_emergency_contact',
#  '\nemergency_phone, Tübingen_emergency_number',
#  '\nemergency_services, Tübingen_emergency_phone',
#  '\nemergency_services, phone_number',
#  '\nemergency_ward, hospital',
#  '\nemergency_ward, walk-in_emergency_ward',
#  '\nemergency_ward_entrance, rescue_service',
#  '\nequestrian center Tübingen',
#  '\nfire_extinguisher Tübingen',
#  '\nfire_hydrant\nTübingen',
#  '\nfire_hydrant\nemergency',
#  '\nfire_hydrant\nemergency_fire_hydrant',
#  '\nfire_hydrant\nemergency_fire_service_inlet',
#  '\nfire_hydrant\nfire_hydrant_location',
#  '\nfire_hydrant\nfire_station',
#  '\nfire_hydrant\npipe',
#  '\nfire_hydrant\nunderground',
#  '\nfire_hydrant\nwater_source',
#  '\nfire_hydrant Ammertalstraße',
#  '\nfire_hydrant Tübingen',
#  '\nfire_hydrant, Tübingen',
#  '\nfire_hydrant, water_source',
#  '\nfire_station, Tübingen',
#  '\nfirepit Tübingen',
#  '\nfitness station, playfit GmbH',
#  '\nfitness_station\ngym',
#  '\nfitness_station, gym',
#  '\nguidepost, Tübingen',
#  '\nguidepost, Tübingen information',
#  '\nguidepost, information',
#  '\nheadshop Tübingen',
#  '\nhistoric cross, Catholic church',
#  '\nhistoric cross, Tübingen city point',
#  '\nhistoric shrine, Catholic church',
#  '\nhistoric shrine, Christian shrine',
#  '\nhistoric site, wayside cross',
#  '\nhistoric wayside_cross\n\n',
#  '\nhistoric, christian_site',
#  '\nhistoric, church',
#  '\nhistoric, religious_site',
#  '\nhistoric, wayside_cross',
#  '\nhistoric,boundary_stone',
#  '\nhistoric_wayside_cross_Tübingen\nstone_monument_T',
#  '\nhitchhiking bench, Tübingen',
#  '\nindoor defibrillator location Tübingen',
#  '\ninformation, Tübingen',
#  '\nlife_ring, emergency_station',
#  '\nlife_ring_location, emergency_service_location',
#  '\nlounge, Cafe',
#  '\nlounger, Tübingen',
#  '\nmemorial, Spende Frau Berta Schüle Kingersheimer Str. 19',
#  '\nmemorial, Tübingen',
#  '\nmemorial, ghost_bike',
#  '\nmulti-storey parking, Tübingen',
#  '\nmusic_school Tübingen',
#  '\nnewsagent, Tübingen',
#  '\npicnic_site, Tübingen',
#  '\npicnic_spot, Tübingen picnic table',
#  '\npicnic_spot, Tübingen picnic table location',
#  '\npicnic_spot, outdoor_furniture',
#  '\npicnic_spot, outdoor_seating',
#  '\npicnic_table, Tübingen',
#  '\npicnic_table, outdoor_furniture',
#  '\nplayground Tübingen',
#  '\nplayground private property Tübingen\n\n',
#  '\nplayground sand Tübingen',
#  '\nplayground, Tübingen',
#  '\nplayground, accessible_playground',
#  '\nplayground, roundabout',
#  '\npost_box, Tübingen',
#  '\npost_box, Tübingen collection times',
#  '\npost_office, Rottenburg am Neckar',
#  '\npost_office, mailbox',
#  '\npublic_transport_tickets, vending_machine',
#  '\nrecycling center, Tübingen',
#  '\nrecycling center, glass bottles collection point',
#  '\nrecycling center, glass bottles recycling Tübingen',
#  '\nrecycling center, scrap metal\n\n',
#  '\nrecycling center, waste management',
#  '\nrecycling center, waste management center',
#  '\nrecycling container Tübingen',
#  '\nrecycling container, Tübingen',
#  '\nrecycling container, glass bottles',
#  '\nrecycling container, glass bottles recycling Tübingen',
#  '\nsoccer_field, Tübingen_soccer_field',
#  '\nsolar_roof_Tübingen\nphotovoltaic_panel',
#  '\ntable tennis court Tübingen',
#  '\ntable tennis court, Tübingen',
#  '\ntable tennis court, outdoor sports facility',
#  '\ntable tennis court, sports facility',
#  '\ntable_tennis_court Tübingen',
#  '\ntable_tennis_venue\ntable_tennis_club',
#  '\ntable_tennis_venue\ntennis_club\n\n',
#  '\ntaxi stand, Tübingen\n\n',
#  '\ntaxi stand, taxi rank',
#  '\ntourism, information',
#  '\ntourist information, Tübingen map',
#  '\ntourist information, guidepost',
#  '\ntourist_information, map_location',
#  '\ntrash bin, waste basket',
#  '\ntrash_bin, waste_management',
#  '\nvending machine, Tübingen',
#  '\nvending machine, chewing gums;toys',
#  '\nvending machine, dog station',
#  '\nvending machine, dog waste bin',
#  '\nvending machine, dog waste disposal',
#  '\nvending machine, excrement bags',
#  '\nvending machine, parking tickets',
#  '\nvending machine, public restroom',
#  '\nvending machine, public waste bin',
#  '\nvending machine, snacks',
#  '\nvending machine, street lamp',
#  '\nviewpoint, Bismarckturm Tübingen',
#  '\nviewpoint, Tübingen',
#  '\nwaste_basket Tübingen',
#  '\nwaste_basket street_lamp Tübingen',
#  '\nwaste_basket, Tübingen',
#  '\nwaste_basket, covered_waste_bin',
#  '\nwaste_basket, dog_excrement',
#  '\nwaste_basket, trash_can',
#  '\nwaste_disposal, private_property',
#  '\nwaste_disposal_site, recycling_center',
#  '\nwater_tank, Tübingen',
#  '\nwayside_cross, Tübingen\n\n',
#  ' Recycling Center, Green Waste\n\n',
#  ' Recycling center, Container depot',
#  ' Recycling center, Tübingen',
#  ' Recycling container, Glass bottles recycling',
#  ' recycling container, glass bottles',
#  ' recycling container, recycling glass bottles',
#  ' waste_basket, street_lamp'}

# %%
with open('../data/llm_keywords.json', 'w') as fp:
    json.dump(list(keywords), fp)

# %%
with open('../data/llm_keywords.json', 'r') as fp:
    keywords = json.load(fp)

print(f"Found {len(keywords)} unique keywords!")

def clean_search_keywords(query):
    """
    Clean up the query to remove newlines
    """

    query = query.strip()
    return query

keywords = list(map(clean_search_keywords, keywords))
keywords
# Out:
# Found 692 unique keywords!
# ['',
#  'Monument, Memorial Plaque',
#  'recycling container, glass bottles',
#  'Parking Underground Entrance, Tübingen',
#  '"Waldtoilette Tübingen"\n"Ökologisches',
#  'Parking, Tübingen',
#  'Memorial, Seifert Brunnen',
#  'Outdoor Seating Area, Public Bench',
#  'shrine, Tübingen memorial',
#  'Park bench, Outdoor seating',
#  'picnic_spot, outdoor_seating',
#  'table tennis court, outdoor sports facility',
#  'lounge, Cafe',
#  'Outdoor Seating, Park Bench',
#  'Artwork, Relief',
#  'defibrillator, Tübingen city hall',
#  'table tennis court Tübingen',
#  'bicycle parking, stands (Tübingen)',
#  'Recycling container, Glass bottles recycling',
#  'Outdoor furniture, Concrete bench',
#  'Outdoor seating, Bench',
#  'Recycling Center, Paper Recycling',
#  'vending machine, dog station',
#  '"Defibrillator location, Volksbank Tübingen"',
#  'Parking Entrance/Exit, Tübingen',
#  'Tübingen viewpoint, Tübingen direction SE-NW',
#  'Post office, Mailbox',
#  'Recycling Container, Paper Recycling',
#  'Parking, Public Space',
#  'Recycling Center, Plastic Bin',
#  'Public Toilets, Accessible Toilets, Tübingen, Kreuzg',
#  'Public Transport Tickets Vending Machine Tübingen',
#  'Multi-storey Car Park, Tübingen',
#  'defibrillator location, Lehrerumkleide (EG)',
#  'Parking, Rathaus Mitarbeiter (Tübingen)',
#  'Emergency, Defibrillator',
#  'historic, wayside_cross',
#  'Parking, Accessible',
#  'tax_advisor Tübingen',
#  'picnic_table, Tübingen',
#  'Shelter, Emergency shelter',
#  'headshop Tübingen',
#  'historic cross, Catholic church',
#  'vending machine, chewing gums;toys',
#  'Recycling Center, Metal Scrap Yard',
#  'Biergarten Tübingen, Limited Accessibility Biergarten Tübing',
#  'emergency_phone, Tübingen_emergency_number',
#  'Parking Tickets Vending Machine',
#  'Outdoor dining, Restaurant',
#  'recycling container, glass bottles',
#  'Parking Space, Tübingen',
#  'defibrillator location, Service-Center Bauen',
#  '"Bench, Wooden"',
#  'Clock, Street Facing',
#  'emergency_ward, walk-in_emergency_ward',
#  'waste_basket, trash_can',
#  'Underground Parking, Tübingen',
#  'defibrillator, Information beim Leergutautomat',
#  'bicycle parking Tübingen',
#  'tourist information, guidepost',
#  'vending machine, cigarettes and telephone vouchers',
#  'Parking, Free Parking',
#  'Historical Column for Horse Tethering, Accessible',
#  'Parking, Street-side Parking',
#  'defibrillator location, Sanitätsraum',
#  'Pub, Tübingen',
#  'recycling center, Tübingen',
#  'taxi stand, Tübingen',
#  'waste_disposal_site, recycling_center',
#  'bicycle repair station Tübingen',
#  'place_of_worship, Catholic church',
#  'defibrillator location, Tübingen Friedrichstraße 21',
#  'Outdoor seating area, Public bench',
#  'Emergency Access, Lift-Gated Destination',
#  'Bicycle parking, Lockers (with fee)',
#  'Motorcycle parking Tübingen',
#  'trash bin, waste basket',
#  'defibrillator location, Tübingen office building',
#  'Historic ruins, Tübingen military site',
#  'equestrian center Tübingen',
#  'guidepost, Tübingen',
#  'Delivery point, Access point',
#  'defibrillator location, Tübingen Frischlinstraße 4',
#  'Parking, Private Parking',
#  'Picnic site, Firepit',
#  'Historic cross, Tübingen (Germany)',
#  'Picnic area, Tübingen',
#  'vending machine, dog waste bin',
#  'post_office, mailbox',
#  'Parking Entrance, Private Parking',
#  'Parking Bollard',
#  'Recycling container, Glass bottles',
#  'Public Toilets, Limited Accessibility Tübingen',
#  'Tübingen, Guidepost',
#  'waste_basket, trash_can',
#  'Trolley Bay, Parking',
#  'defibrillator location, Kingersheimer Straße',
#  'lounger, Tübingen',
#  'private toilets Tübingen',
#  'life_ring, emergency_station',
#  'Parking Entrance, Private Parking',
#  'Parking, Handicapped Parking',
#  'Sanitary Dump Station, Tübingen',
#  'Tourist Information, Schönbuch Hiking Trails',
#  'Parking Tickets Vending Machine, Tübingen',
#  'memorial, Tübingen',
#  'Parking, Private Parking',
#  'Parking Tickets Vending Machine',
#  'fitness_station\ngym',
#  'Chess Table, Outdoor Recreation',
#  'Parking Entrance Tübingen',
#  'Waldlehrpfad Einsiedel, Tübingen',
#  'Hunting_stand Tübingen',
#  'defibrillator, indoor_location',
#  'bus_stop, public_transportation',
#  'indoor defibrillator location Tübingen',
#  'Parking Entrance, Gate',
#  'viewpoint Tübingen',
#  'defibrillator location, office parking',
#  'Fitness Station, Elliptical Trainer',
#  'defibrillator location, Schmiedtorstraße 4, 7207',
#  'Drinking water fountain, Public tap',
#  'Public Transport Tickets Vending Machine (Indoor) Tübingen',
#  'Public Bookcase Shelf',
#  'table_tennis_venue\ntennis_club',
#  'Fire_hydrant\nEmergency_services_facility',
#  'Recycling, Waste Bin',
#  'bicycle parking, wall loops',
#  'Tourist Information, Wildlife Board',
#  'Firepit location, Tübingen',
#  'recycling center, glass bottles collection point',
#  'emergency_phone, Tübingen_emergency_contact',
#  'Parking Entrance, Tübingen',
#  '"Medieval archaeological site, Tübingen"',
#  'Outdoor Furniture, Public Seating',
#  'bbq_grill_location, Tübingen_grill_spot',
#  'water_tank, Tübingen',
#  'Garbage bin, Recycling point',
#  'viewpoint, Tübingen',
#  'waste_basket, covered_waste_bin',
#  'Park bench, Seating area',
#  'Public Toilets, Tübingen (limited wheelchair access)',
#  'Picnic site, BBQ area',
#  '"Public seating, Tübingen"',
#  'historic_boundary_stone',
#  'playground, accessible_playground',
#  'vending machine, excrement bags',
#  'Tübingen Hbf, Guidepost',
#  '"Sculpture, Vogel"',
#  'Recycling Center, Glass Bottles Recycling',
#  '"Park bench, Tübingen"',
#  'Outdoor furniture, Bench',
#  'Outdoor seating, Park bench',
#  'Trash bin, Waste basket',
#  'bicycle repair station, Tübingen',
#  'defibrillator location, emergency services',
#  'Picnic_spot, Tübingen',
#  'Restaurant, Outdoor dining',
#  'Historical Linden Allee, Memorial',
#  'vending machine, parking tickets',
#  'vending machine, drinks',
#  'clock, sundial',
#  'Outdoor seating, Table tennis',
#  'vacant shop',
#  'Park bench, Tübingen city',
#  'Barbecue, Tübingen',
#  'Trolley_bay, Parking',
#  'Parking, Surface Parking',
#  'Memorial Stele, Tübingen 2008',
#  'fire_extinguisher Tübingen',
#  'Excrement Bags Vending Machine Tübingen',
#  'Parking space, Disabled parking',
#  'Monument, Boundary_stone',
#  'Viewpoint, Bench',
#  'Dentist, Tübingen Dental Clinic',
#  'Recycling center, Tübingen',
#  '"Park bench, Wooden bench"',
#  'fire_hydrant\nTübingen',
#  '"Public Fountain (No Drinking Water)"',
#  'Litter bin, Steel litter bin',
#  'Rottenburg am Neckar, Physiotherapist',
#  'artwork, sculpture',
#  'bicycle parking stands Tübingen',
#  'Tübingen Information Board, Tübingen Tourist Information',
#  'Bicycle parking, Tübingen',
#  'Outdoor Seating, Bench',
#  'fitness_station, gym',
#  'Milestone, Kilometerstein',
#  'memorial stone Tübingen',
#  'bicycle parking, lockers',
#  'vacant cafe Tübingen',
#  'hiking, Ammertal',
#  'assembly_point Tübingen',
#  'guidepost, Tübingen',
#  'emergency, defibrillator',
#  'waste_basket street_lamp Tübingen',
#  'Picnic table, Bench',
#  'Shelter, Tübingen',
#  'Rottenburg am Neckar, Storage Rental',
#  'picnic_spot, outdoor_furniture',
#  'Recycling, Metal Recycling',
#  'emergency_ward_entrance, rescue_service',
#  'Underground Parking, Tübingen',
#  '"Tübingen, Germany, Accessible, Emergency"',
#  'Tour, Information (or) Vesper-Tour, Information (or) H',
#  'Park bench, Public shelter',
#  'sculpture, Gôgen-Denkmal',
#  'Bicycle parking, Wall loops',
#  'Guidepost, Information',
#  'Firepit Tübingen',
#  'Tourist Information, Historical Map',
#  'picnic_spot, Tübingen picnic table',
#  'Memorial bench, St. Remigius Chapel',
#  'memorial, Karl Stanik',
#  'vending machine drinks Tübingen',
#  'Fountain, Tübingen (City)',
#  'Recycling Center, Waste Bin',
#  'Picnic table, Holzacker park, Tübingen-Hirschau',
#  'Bicycle parking stands, Covered bicycle parking Tübingen',
#  'Underground Concrete Parking',
#  'waste_disposal, private_property',
#  'Vending machine, Drinks (Tübingen)',
#  'Photovoltaic System, Solar Energy',
#  'Outdoor seating, Bench (8 seats)',
#  'recycling center, scrap metal',
#  'Guidepost, Information',
#  'Clock tower, City center',
#  'Gomaringen, Bahnhofstraße',
#  'historic,boundary_stone',
#  'Cigarette vending machine, Tübingen',
#  'Barbecue Grill, Tübingen',
#  'Outdoor furniture, Bench (No backrest)',
#  'Park bench, Altliege',
#  'Parking, Surface parking',
#  'Coffee Shop, Snack Bar',
#  'Hunting stand, Shooting range',
#  'Artwork, Tübingen',
#  'Underground parking, Tübingen',
#  'Outdoor seating, Concrete bench',
#  'historic wayside_cross',
#  'memorial, Tübingen',
#  'Hunting_stand Tübingen',
#  'vending machine, excrement bags',
#  'memorial plaque Tübingen',
#  'Parking Garage, Underground Parking',
#  'Street parking Tübingen',
#  'loading_dock, Tübingen',
#  'Recycling Container, 24/7 Glass Bottles Recycling (Whe',
#  'Waldlehrpfad, Tübingen',
#  'Public Toilets, Accessible Toilets',
#  'Water tap, Drinking water',
#  'Motorcycle parking, Bicycle parking (wall_loops)',
#  'Recycling Center, Winter Collection Point',
#  'bar, Tübingen',
#  'vending machine, sweets',
#  'post_office, Rottenburg am Neckar',
#  'viewpoint, Tübingen',
#  'Outdoor seating area, Tübingen',
#  'Café, Outdoor seating',
#  'Outdoor Seating, Stone Bench',
#  'fire_hydrant\npipe',
#  'Elevator, Building Entrance',
#  'Parking Entrance Tübingen',
#  'defibrillator location, Tübingen 58 Aixer Straße',
#  'Outdoor seating, Public bench',
#  'Recycling Center, Waste Management',
#  'defibrillator location, Tübingen city hall',
#  'Recycling Center, Green Waste',
#  'Clock tower, Tübingen city center',
#  'recycling container, Tübingen',
#  'taxi stand, Tübingen',
#  'Recycling Center, Plastic Recycling',
#  'Recycling, Waste Management',
#  'Outdoor furniture, Seating area',
#  'playground private property Tübingen',
#  'Bicycle parking Tübingen',
#  'fire_hydrant, Tübingen',
#  'Underground Parking Tübingen',
#  'Outdoor shelter, Waldkindergarten Veranda',
#  'Public Bookcase, Outdoor Library',
#  'Naturschutzgebiet, Viewpoint',
#  'Ticket Validator Kiosk, Public Transport',
#  'music_school Tübingen',
#  '"Park bench, Seating area"',
#  'Public Transport Tickets Vending Machine, Tübingen',
#  'historic_wayside_cross_Tübingen\nstone_monument_T',
#  'drinking water, fountain',
#  'fire_hydrant, water_source',
#  'Picnic Area, Tübingen',
#  'Shelter, Bühlerwald-Hütte',
#  'wayside shrine, Christian shrine',
#  'Parking Garage, Underground Parking',
#  'Multi-storey Car Park, Tübingen',
#  'Recycling container, Glass bottles recycling',
#  'multi-storey parking, Tübingen',
#  'recycling container, glass bottles recycling Tübingen',
#  'car_repair Tübingen',
#  'Tübinger Straße, Tübingen',
#  'Public Toilets, Tübingen',
#  'vending machine, chewing gums',
#  'Defibrillator Location, Sporthalle Tübingen',
#  'Equestrian field, Tübingen',
#  'table_tennis_venue\ntable_tennis_club',
#  'Viewpoint, Limited Accessibility',
#  'Outdoor furniture, Bench (no backrest)',
#  'Tübingen deer feeding area, Deer feeding point Tübingen',
#  'Rottenburg am Neckar, Maieräckerstraße 18',
#  'Public Toilets (Paid)',
#  'Parking, Destination',
#  'Soccer field, Grass pitch',
#  'Bicycle parking, Indoor bicycle parking',
#  'Park bench, Sitzbank',
#  '"Bench, Inscription"',
#  'Viewpoint, Panorama Tübingen',
#  'Public Bookcase, Wooden Cabinet',
#  'picnic_spot, Tübingen picnic table location',
#  'bicycle parking, stands (5412419730)',
#  'playground, Tübingen',
#  'Fountain, Tübingen',
#  'Multi-storey Car Park, Parking Entrance',
#  'post_box, Tübingen',
#  'waste_bin, dog_waste_bin',
#  'life_ring_location, emergency_service_location',
#  'Picnic site, Grillplatz bei Entringen (Google search: "Pic',
#  'Historic Boundary Stone, Tübingen City',
#  'Parking, Disabled Parking',
#  'Outdoor furniture, Wooden bench (Not backrest)',
#  'fire_hydrant Tübingen',
#  'bollard, parking',
#  'table tennis court, Tübingen',
#  'Recycling Center, Bischof-Moser-Straße',
#  'Underground Parking Entrance, Tübingen',
#  'Fountain, Erbsenbrunnen',
#  'Picnic spot, Outdoor seating',
#  'Hunting stand, Tübingen',
#  'charging_station Tübingen',
#  'building shed Tübingen',
#  'Tübingen, Ehinger Platz',
#  'Outdoor Seating Area\nPublic Bench',
#  'Tourism, Information',
#  'Parking Tickets Vending Machine, Accessible',
#  'bbq_area, public_bbq_spot',
#  'Bicycle parking stands, Covered bicycle parking',
#  '"Outdoor seating, Concrete bench"',
#  'climbing wall\ntübingen climbing wall\n(or)\nclimbing',
#  'Public Toilets, Mobile Toilet Cabin',
#  'Historic cross, Vandalized cross',
#  'Park bench, Plastic bench',
#  'historic shrine, Christian shrine',
#  'tourist_information, map_location',
#  'bicycle parking Tübingen',
#  'Clock, Street',
#  'Dog waste bin, Tübingen',
#  'tourist information, Tübingen map',
#  'Telephone booth, Accessible telephone booth',
#  'Bicycle parking, Wall loops parking Tübingen',
#  'Hunting stand, Tübingen',
#  'Weather shelter, Emergency shelter',
#  '"Fountain, Tübingen"',
#  'hitchhiking bench, Tübingen',
#  'artwork Tübingen',
#  'historic site, wayside cross',
#  'Compressed Air Station Fee\nCompressed Air Station Paid Access',
#  'Outdoor seating area, Park bench',
#  'Tübingen viewpoint, Accessible viewpoint',
#  'tourism, information',
#  '"Concrete bench, Tübingen"',
#  'Table Tennis Court, Tübingen',
#  'Trash bin, Waste basket Tübingen',
#  'Relaxbank Bench',
#  'picnic_site, Tübingen',
#  'fire_hydrant Ammertalstraße',
#  'defibrillator location, Gymnastikraum Tübingen',
#  'Historical Column, Pferdeanbinden (Historical Horse Tethering',
#  'Tübingen, City Hall',
#  'Toy Vending Machine (Indoor)',
#  'guidepost, information',
#  'Compressed Air Station, Tübingen',
#  'Tübingen History Board, Tübingen Tourist Information',
#  'defibrillator location, Hügelstraße 13, 7207',
#  'Parking Tickets Vending Machine Tübingen',
#  'Parking, Limited Accessibility',
#  'vending machine, snacks',
#  'Emergency Ward Entrance, Rescue Service',
#  'Bicycle parking stands, Tübingen',
#  'Tübingen History Board, Tübingen Information Board',
#  'guidepost, Tübingen information',
#  'Paid parking space, Disabled parking space',
#  'Hunting stand, Tübingen',
#  'recycling container Tübingen',
#  'Basketball court, Tübingen',
#  'Tübingen wildlife board, Tübingen information board',
#  'Public Toilets, Tübingen (limited wheelchair accessibility)',
#  'Public Toilets for Wheelchair Users, Accessible Toilets Tübingen',
#  'Recycling container, Glass bottles recycling Tübingen',
#  'Multi-storey Car Park, Parking Entrance',
#  'Cafe, Tübingen',
#  '24/7 defibrillator, Indoor defibrillator',
#  '24/7 Farm Store, Tübingen',
#  'bench, Tübingen',
#  'Parking, Paid Parking',
#  'Fire hydrant location, Emergency services Tübingen',
#  'Tourist Information, Guidepost',
#  'Bicycle parking, Safe loops parking Tübingen',
#  'playground sand Tübingen',
#  'bicycle parking, emergency parking',
#  'bench, seating',
#  'defibrillator location, emergency services',
#  'Historic Cross, Conciliation Cross',
#  'bicycle parking, stands (8)',
#  'fire_hydrant\nunderground',
#  'playground, roundabout',
#  'Picnic Table, Tübingen',
#  'vending machine, Tübingen',
#  'Trash bin, Waste basket (Tübingen)',
#  'fire_hydrant\nemergency_fire_service_inlet',
#  'vending machine, street lamp',
#  'Park bench, Accessible',
#  'Barbecue area, Fire pit location',
#  'Public Bookcase 24/7',
#  'Parking Entrance, Surface Parking',
#  'defibrillator, emergency_services',
#  'Historic Catholic Cross, Tübingen',
#  'playground Tübingen',
#  'bicycle parking, Tübingen',
#  'charging_station, Tübingen',
#  'waste_basket, street_lamp',
#  'emergency_ward, hospital',
#  'guidepost, Tübingen city center',
#  'Parking, Accessible Parking',
#  'Public Toilets\nNot Accessible for Wheelchair Users',
#  'Café, Lounger',
#  'defibrillator, emergency_station',
#  'Accessible Public Toilets, Tübingen',
#  'vending machine, dog waste disposal',
#  'vending machine, Tübingen',
#  'Parking Entrance, Private Parking',
#  'vacuum_cleaner_rental_Tübingen\nvacuum',
#  'defibrillator location, Tübingen address',
#  'Recycling Center, Trash Can',
#  'Tourism, Guidepost',
#  'Parking, Street Side Parking',
#  'emergency_services, phone_number',
#  'Recycling Center, Trash Disposal Facility',
#  'defibrillator, indoor_facility',
#  'acupuncture clinic, healthcare Tübingen',
#  'Free parking, Wheelchair accessible parking',
#  'accessible, emergency_services',
#  'Parking Underground, Tübingen',
#  'Outdoor Seating Area, Park Bench',
#  'defibrillator location, indoor emergency',
#  'emergency_services, Tübingen_emergency_phone',
#  'memorial, Spende Frau Berta Schüle Kingersheimer Str. 19',
#  '"Outdoor furniture, Park bench"',
#  'defibrillator location, Halle 3 Sanitätsraum',
#  'memorial, ghost_bike',
#  'Telephone booth\nPublic call box',
#  'historic,boundary_stone',
#  'Car wash, Tübingen',
#  'Regina Burckhardt-Bardili; Memorial Plaque',
#  'Picnic spot, Tübingen',
#  'fire_hydrant\nemergency',
#  'Parking, Asphalt Surface',
#  'tourist information, guidepost',
#  'Chess Ground, Tübingen',
#  'Barbecue area, Tübingen',
#  'Fountain, Tübingen (City Name)',
#  'Grill, Barbecue',
#  'Emergency Barrier',
#  'Underground parking Tübingen',
#  'Ghost bike, Memorial',
#  'Public Toilets with Wheelchair Access, Paid Toilets',
#  'Tübingen, Massage',
#  'Emergency bollard, Removable bollard',
#  'Outdoor Furniture, Bench (No Backrest)',
#  'Outdoor furniture, Wooden bench',
#  'taxi stand, taxi rank',
#  'archaeological site, Tumulus',
#  'Public Library\nBook Exchange',
#  'Public Transport Tickets, Vending Machine',
#  'Vending Machine, Drinks 24/7 Tübingen',
#  'historic, church',
#  'Outdoor furniture, Park bench',
#  'table tennis court, sports facility',
#  'Basketball court, Outdoor basketball court',
#  'Kaiser Augustus Statue Memorial Tübingen',
#  'Underground Parking Entrance, Tübingen',
#  'telephone booth\npublic call box',
#  'Outdoor Furniture, Stone Bench',
#  'Tübingen bench, Christiane Nüsslein-Volhard dedication',
#  'Drinking water fountain, Accessible drinking water fountain',
#  'vending machine, sweets shop',
#  'Tourist Information, Nature Board',
#  'Fountain, Nervenklinik Tübingen',
#  'trash_bin, waste_management',
#  'historic, religious_site',
#  'solar_roof_Tübingen\nphotovoltaic_panel',
#  'soccer_field, Tübingen_soccer_field',
#  'historic shrine, Catholic church',
#  'atm machine bank cashpoint Tübingen',
#  'Picnic shelter, Tübingen',
#  'recycling center, waste management',
#  'Recycling Container, Glass Bottles Recycling',
#  'table_tennis_court Tübingen',
#  'defibrillator location, Nonnengasse 19, 7207',
#  'Litter bin, Steel bin',
#  'defibrillator location, Volksbank Tübingen',
#  'Ruins of Tübingen, Tübingen historic sites',
#  'Historic water well, out of order',
#  'Outdoor furniture, Blue bench',
#  'Recycling bin, Green metal bin',
#  'Bicycle parking, Covered bicycle parking',
#  'doctors, Tübingen',
#  'historic cross, Tübingen city point',
#  'Tübingen, Guidepost',
#  'Drinking water fountain, Public water fountain',
#  'Tourist Information, Historical Board',
#  'Public Transport Tickets Vending Machine, Tübingen',
#  'Public Table Tennis Court\nTable Tennis Facility',
#  'waste_basket, Tübingen',
#  'recycling center, glass bottles recycling Tübingen',
#  'Parking, Private',
#  'Tourist Information, Information Board',
#  'picnic_table, outdoor_furniture',
#  'post_box, Tübingen collection times',
#  '"Statue of Nymph, Tübingen art"',
#  'bench, seating',
#  'bicycle parking, Tübingen',
#  'Tourist Information, Map Information',
#  'Guidepost;Information',
#  'Fountain, Eberhardskirche Tübingen',
#  'Historic Fountain, Tübingen Marktplatz Entringen',
#  'fire_hydrant\nfire_hydrant_location',
#  'Viewpoint, Tübingen',
#  '"Metal bench, Tübingen"',
#  'Historic boundary stone, Tübingen inscription',
#  'Vending machine, Cigarettes',
#  'doctors, Tübingen',
#  'Tübingen History, Tübingen Tourism Information',
#  'drinking water fountain',
#  'Public Shower\nPublic Shower Facility',
#  'waste_basket, dog_excrement',
#  'defibrillator location, Tübingen 72072 Galgenberg',
#  'Park bench, Wooden bench',
#  'Decorative Fountain',
#  'Tourist Information, Geology Information',
#  'defibrillator location, indoor emergency',
#  'recycling center, waste management center',
#  'Picnic spot, Wooden picnic table',
#  'Outdoor furniture, Wooden bench',
#  'defibrillator location, Tübingen',
#  'Picnic Spot, Private Area',
#  'Recycling Center, Container Depot',
#  'Recycling center, Container depot',
#  'Historic water well, Tübingen',
#  'Private parking, Surface parking',
#  'Clock, Sundial (Indoor)',
#  'Free parking, Accessible parking',
#  'defibrillator, Tübingen University Hospital (implied by indoor and location',
#  'Artist, Martin',
#  'guidepost, information',
#  'Underground parking, Tübingen',
#  '"Outdoor seating, Wooden bench"',
#  'fire_hydrant\nwater_source',
#  'Recycling Center, Waste Disposal',
#  'Tübingen, Marktstraße 11, 82606',
#  'Recycling container for glass bottles, Tübingen',
#  'vending machine, cigarettes',
#  'drinking_water_tap, city_water_source',
#  'lounge, Cafe',
#  'viewpoint, Bismarckturm Tübingen',
#  'Parking, Königstraße 11, Tübingen',
#  'Viewpoint, Tübingen',
#  'fire_hydrant\nfire_station',
#  'newsagent, Tübingen',
#  'historic shrine, Christian shrine',
#  'Tourist Information, Board',
#  'memorial cross Tübingen',
#  'Outdoor wooden public bookcase',
#  'recycling container, recycling glass bottles',
#  '"Defibrillator location Tübingen"\n"Emergency defibr',
#  'cafe Tübingen',
#  'Firepit, Barbecue',
#  'Rottenburg am Neckar, Convenience Store',
#  'Parking, Visitor Parking',
#  'Memorial, Stele',
#  'Emergency, Defibrillator',
#  'Memorial, Cemetery',
#  'vending machine, public waste bin',
#  '"Bench, Tübingen"',
#  'Outdoor seating, Stone bench',
#  'Historic Cross, Wayside Cross',
#  'waste_basket Tübingen',
#  'church, Tübingen Catholic Church',
#  'Rottenburg am Neckar, Vacant Shop',
#  'fire_station, Tübingen',
#  'emergency_ward, hospital',
#  'Park bench, Tübingen',
#  'Picnic site, Tübingen',
#  '"Sitzbank, Tübingen"',
#  'telephone_booth\npublic_call_box',
#  'Artwork, Historic',
#  'vending machine, public restroom',
#  'Tourist Information, Notice Board',
#  'Outdoor Seating Area\nPark Bench',
#  'Emergency, Bollard (Rising)',
#  'defibrillator Tübingen',
#  'lounger, Tübingen',
#  'Historic boundary stone, Tübingen city symbol',
#  'Tübingen viewpoint, Limited accessibility viewpoint',
#  'Tourist Information, Zick-Zack-Wegle',
#  'Public Toilets, Tübingen',
#  'memorial, Entringens',
#  'sculpture, Tübingen art',
#  'Tourist Information, Guidepost',
#  'Public Toilets with Wheelchair Access and Changing Table, Free of Charge (',
#  'canteen, Tübingen',
#  'Monument, Inscription',
#  'Tourist Information, Geology Map',
#  'Historic Boundary Stone, Tübingen City Hall',
#  'Picnic site, Barbecue area',
#  'Park, Dog Waste Bin',
#  'wayside_cross, Tübingen',
#  'Recycling Center, Wood Collection Point',
#  'firepit Tübingen',
#  'Bicycle parking, Wall loops parking',
#  'Fountain Tübingen',
#  'Park bench, Altliege (Tübingen)',
#  'historic, christian_site',
#  'Shelter with fireplace Tübingen',
#  'public_transport_tickets, vending_machine',
#  'fire_hydrant\nemergency_fire_hydrant',
#  'Outdoor Furniture, Park Bench',
#  'letter_box, Tübingen',
#  'Parking, Gravel Parking',
#  'bicycle parking, stands',
#  'bench, Tübingen',
#  'Bicycle parking, Stand',
#  'information, Tübingen',
#  'fitness station, playfit GmbH',
#  'Emergency Barrier, Lift Gate Tübingen',
#  'Clock, Sundial',
#  'Outdoor Seating, Stone Bench',
#  'Tourist Information, Geology Map',
#  'Tourist Information, Nature Board',
#  'Tourism, Information',
#  'hiking, Ammertal',
#  'Tübingen, Guidepost',
#  'Tourist Information, Geology Information',
#  'Picnic site, Tübingen',
#  'Tourist Information, Information Board',
#  'Tourist Information, Zick-Zack-Wegle',
#  'tourist information, guidepost',
#  'guidepost, information',
#  'Viewpoint, Bench',
#  'Tourist Information, Guidepost',
#  'Tübingen Hbf, Guidepost',
#  'Viewpoint, Tübingen',
#  'artwork, sculpture',
#  'Tourist Information, Historical Board',
#  'Tübingen, Guidepost',
#  'tourist_information, map_location',
#  'guidepost, information',
#  '"Statue of Nymph, Tübingen art"',
#  'tourist information, guidepost',
#  'Tourist Information, Historical Map',
#  'guidepost, Tübingen',
#  'Viewpoint, Panorama Tübingen',
#  'viewpoint, Tübingen',
#  'Artist, Martin',
#  'Artwork, Relief',
#  'tourist information, route marker',
#  'tourism, information',
#  'Tourist Information, Board',
#  'tourist information, bicycle guidepost',
#  'Tübingen guidepost, LCN network information',
#  'Tourist Information, Guidepost',
#  'Tübingen;Guidepost;Information',
#  'Tübingen, Guidepost',
#  'Tourist Information, Lebendiger Wald',
#  'Tübingen, City Tourism Information',
#  'guidepost, information',
#  'tourist information, guidepost',
#  'Lebendiger Wald, Feuchtbiotope',
#  'route_marker, tourism',
#  'Lebendiger Wald, Tübingen',
#  'guidepost, information',
#  'tourism, information',
#  'route_marker, information',
#  'tourist information, guidepost',
#  '"Lebendiger Wald, Elchtest"',
#  'Garden, Tübingen']

# %% [markdown]
# #### Search Keywords
#
# We now have the following:
# 1. ~700 keywords generated from unnamed nodes in and around Tübingen.
# 2. ~6K Named nodes, some of them with URLs.
#
# We now need to use this information to create a large frontier of URLs for our crawler to crawl from. We start by aggregating all of our search keywords into a file. We also dump all direct URLs into a file for later use.

# %%
all_search_keywords = set()
frontier_urls = set()

all_search_keywords.update(keywords)


for node in nodes_with_info:

    # If this node has a name, add it to the search keywords list.
    if 'name' in node['tags']:
        all_search_keywords.add(node['tags']['name'] + ' Tübingen')

    if 'operator'in node['tags']:
        all_search_keywords.add(node['tags']['operator'] + ' Tübingen')

    # If this node has any reference URLs, add it to the frontier as well.
    for value in node['tags'].values():
        if validators.url(value):
            frontier_urls.add(value)


print(f"Final count of search keywords: {len(all_search_keywords)}")
print(f"Count of initial fontier obtained from direct URLs: {len(frontier_urls)}")
# Out:
# Final count of search keywords: 4715
# Count of initial fontier obtained from direct URLs: 1415

# %%
# Save all the search keywords and URLs in JSON files.

with open('../data/search_keywords.json', 'w') as fp:
    json.dump(list(all_search_keywords), fp)

with open('../data/frontier_urls_initial.json', 'w') as fp:
    json.dump(list(frontier_urls), fp)
